# %% [markdown]
# <a href="https://colab.research.google.com/github/swethaselvarajm/ANALYSIS-OF-CRIME-AGAINST-INDIAN-WOMEN-BY-TIME-SERIES-AND-MACHINE-LEARNING-ALGORITHMS-/blob/main/final_MINI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages and setup
# !pip install matplotlib seaborn statsmodels plotly
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Load and Clean Dataset
file_path = '/content/CrimesOnWomenData-dataset.csv'  # Replace with your dataset path
df = pd.read_csv(file_path)
data_cleaned = df.drop(columns=['Unnamed: 0'])  # Remove unnecessary column
statewise_data = data_cleaned.groupby(['State', 'Year']).sum().reset_index()

# Define the crime types
crime_types = ['Rape', 'Kidnapping and Abduction', 'Dowry Deaths',
               'Assault on women with intent to outrage her modesty',
               'Insult to modesty of Women', 'Cruelty by Husband or his Relatives']

# %%
# Standardize state names
df.loc[df['State'] == 'A&N Islands', 'State'] = 'A & N ISLANDS'
df.loc[df['State'] == 'D&N Haveli', 'State'] = 'D & N HAVELI'
df.loc[df['State'] == 'Delhi UT', 'State'] = 'DELHI'
df['State'] = df['State'].str.upper()  # Convert all states to uppercase

# %%
# View initial data details
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           736 non-null    int64
#  1   State                                                736 non-null    object
#  2   Year                                                 736 non-null    int64
#  3   Rape                                                 736 non-null    int64
#  4   Kidnapping and Abduction                             736 non-null    int64
#  5   Dowry Deaths                                         736 non-null    int64
#  6   Assault on women with intent to outrage her modesty  736 non-null    int64
#  7   Insult to modesty of Women                           736 non-null    int64
#  8   Cruelty by Husband or his Relatives                  736 non-null    int64
#  9   Importation of Girls                                 736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB
# None

# %%
print(df.describe(include='all'))
# Out:
#         Unnamed: 0           State         Year         Rape  \
# count   736.000000             736   736.000000   736.000000
# unique         NaN              36          NaN          NaN
# top            NaN  ANDHRA PRADESH          NaN          NaN
# freq           NaN              21          NaN          NaN
# mean    367.500000             NaN  2011.149457   727.855978
# std     212.609188             NaN     6.053453   977.024945
# min       0.000000             NaN  2001.000000     0.000000
# 25%     183.750000             NaN  2006.000000    35.000000
# 50%     367.500000             NaN  2011.000000   348.500000
# 75%     551.250000             NaN  2016.000000  1069.000000
# max     735.000000             NaN  2021.000000  6337.000000
#
#         Kidnapping and Abduction  Dowry Deaths  \
# count                 736.000000    736.000000
# unique                       NaN           NaN
# top                          NaN           NaN
# freq                         NaN           NaN
# mean                 1134.542120    215.692935
# std                  1993.536828    424.927334
# min                     0.000000      0.000000
# 25%                    24.750000      1.000000
# 50%                   290.000000     29.000000
# 75%                  1216.000000    259.000000
# max                 15381.000000   2524.000000
#
#         Assault on women with intent to outrage her modesty  \
# count                                          736.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          1579.115489
# std                                           2463.962518
# min                                              0.000000
# 25%                                             34.000000
# 50%                                            387.500000
# 75%                                           2122.250000
# max                                          14853.000000
#
#         Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# count                   736.000000                           736.000000
# unique                         NaN                                  NaN
# top                            NaN                                  NaN
# freq                           NaN                                  NaN
# mean                    332.722826                          2595.078804
# std                     806.024551                          4042.004953
# min                       0.000000                             0.000000
# 25%                       3.000000                            13.000000
# 50%                      31.000000                           678.500000
# 75%                     277.500000                          3545.000000
# max                    9422.000000                         23278.000000
#
#         Importation of Girls
# count             736.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean               28.744565
# std                79.999660
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                15.000000
# max               549.000000

# %%
print("Unique States:", df['State'].unique())
# Out:
# Unique States: ['ANDHRA PRADESH' 'ARUNACHAL PRADESH' 'ASSAM' 'BIHAR' 'CHHATTISGARH' 'GOA'
#  'GUJARAT' 'HARYANA' 'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'KARNATAKA' 'KERALA' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR' 'MEGHALAYA'
#  'MIZORAM' 'NAGALAND' 'ODISHA' 'PUNJAB' 'RAJASTHAN' 'SIKKIM' 'TAMIL NADU'
#  'TRIPURA' 'UTTAR PRADESH' 'UTTARAKHAND' 'WEST BENGAL' 'A & N ISLANDS'
#  'CHANDIGARH' 'D & N HAVELI' 'DAMAN & DIU' 'LAKSHADWEEP' 'PUDUCHERRY'
#  'TELANGANA' 'DELHI']

# %%
# Storing the sum of all crimes committed within a state (statewise)
state_all_crimes = df.groupby('State').sum()

# Dropping the sum of year column
state_all_crimes.drop('Year', axis=1, inplace=True)

# Adding a column containing the total crime against women in that state
col_list = list(state_all_crimes)

# Convert columns to numeric, coerce errors to NaN to ensure compatibility for summation
state_all_crimes[col_list] = state_all_crimes[col_list].apply(pd.to_numeric, errors='coerce')

# Now you can sum across rows
state_all_crimes['Total'] = state_all_crimes[col_list].sum(axis=1)

# Assigning to all_crimes
all_crimes = state_all_crimes

all_crimes
# Out:
#                    Unnamed: 0   Rape  Kidnapping and Abduction  Dowry Deaths  \
# State
# A & N ISLANDS            7849    424                       363            13
# ANDHRA PRADESH           7250  23424                     21707          8165
# ARUNACHAL PRADESH        7271   1153                      1272             4
# ASSAM                    7292  32190                     71462          2757
# BIHAR                    7313  21006                     77687         24428
# CHANDIGARH               7870    795                      1547            68
# CHHATTISGARH             7334  25178                     16536          1797
# D & N HAVELI             7891   2343                      7148           256
# DAMAN & DIU              7912    619                      1725            30
# DELHI                    6083  13065                     31251          1106
# GOA                      7355   1019                       720            23
# GUJARAT                  7376   9940                     25733           652
# HARYANA                  7397  17776                     29593          5144
# HIMACHAL PRADESH         7418   4474                      4043            76
# JAMMU & KASHMIR          7439   7656                     17464           735
# JHARKHAND                7460  18054                     13604          6814
# KARNATAKA                7481  12723                     15258          6028
# KERALA                   7502  24184                     14056          1525
# LAKSHADWEEP              7944     20                         1             0
# MADHYA PRADESH           7523  72808                     57485         13316
# MAHARASHTRA              7544  39252                     46522          5756
# MANIPUR                  7565    905                      1802             3
# MEGHALAYA                7586   1971                       628            24
# MIZORAM                  7607   1241                        40             5
# NAGALAND                 7628   3037                      9180           615
# ODISHA                   7649  24810                     29847          7521
# PUDUCHERRY               7965    140                       201            48
# PUNJAB                   7670  23062                     24611          2977
# RAJASTHAN                7691  43799                     55320          7769
# SIKKIM                   7712   1237                      1428            71
# TAMIL NADU               7733  11633                     23534          3314
# TELANGANA                5984   5533                      5948          1724
# TRIPURA                  7765   8844                     21390          4976
# UTTAR PRADESH            7786  45694                    133856         40615
# UTTARAKHAND              7807   6207                     20319          2320
# WEST BENGAL              7828  29486                     51742          8075
#
#                    Assault on women with intent to outrage her modesty  \
# State
# A & N ISLANDS                                                    558
# ANDHRA PRADESH                                                 92084
# ARUNACHAL PRADESH                                               1584
# ASSAM                                                          47115
# BIHAR                                                           9953
# CHANDIGARH                                                       954
# CHHATTISGARH                                                   33310
# D & N HAVELI                                                    3977
# DAMAN & DIU                                                     3642
# DELHI                                                          26039
# GOA                                                             1475
# GUJARAT                                                        18116
# HARYANA                                                        24347
# HIMACHAL PRADESH                                                7574
# JAMMU & KASHMIR                                                22850
# JHARKHAND                                                      19771
# KARNATAKA                                                      64492
# KERALA                                                         69081
# LAKSHADWEEP                                                       23
# MADHYA PRADESH                                                152000
# MAHARASHTRA                                                   107519
# MANIPUR                                                         1131
# MEGHALAYA                                                       1160
# MIZORAM                                                         1252
# NAGALAND                                                       27631
# ODISHA                                                         83473
# PUDUCHERRY                                                       870
# PUNJAB                                                         28644
# RAJASTHAN                                                      67855
# SIKKIM                                                          2358
# TAMIL NADU                                                     33885
# TELANGANA                                                      23938
# TRIPURA                                                        23744
# UTTAR PRADESH                                                  99650
# UTTARAKHAND                                                     9160
# WEST BENGAL                                                    51014
#
#                    Insult to modesty of Women  \
# State
# A & N ISLANDS                             135
# ANDHRA PRADESH                          54684
# ARUNACHAL PRADESH                          97
# ASSAM                                    2698
# BIHAR                                     800
# CHANDIGARH                                281
# CHHATTISGARH                             4382
# D & N HAVELI                              840
# DAMAN & DIU                                58
# DELHI                                    6046
# GOA                                       475
# GUJARAT                                  2925
# HARYANA                                 11834
# HIMACHAL PRADESH                         1306
# JAMMU & KASHMIR                          5179
# JHARKHAND                                1572
# KARNATAKA                                3862
# KERALA                                   8873
# LAKSHADWEEP                                11
# MADHYA PRADESH                          21631
# MAHARASHTRA                             30693
# MANIPUR                                    88
# MEGHALAYA                                 108
# MIZORAM                                   162
# NAGALAND                                 1487
# ODISHA                                   7631
# PUDUCHERRY                                343
# PUNJAB                                   2132
# RAJASTHAN                                2365
# SIKKIM                                    118
# TAMIL NADU                              12084
# TELANGANA                                4836
# TRIPURA                                   283
# UTTAR PRADESH                           46524
# UTTARAKHAND                              2591
# WEST BENGAL                              5750
#
#                    Cruelty by Husband or his Relatives  Importation of Girls  \
# State
# A & N ISLANDS                                      365                    10
# ANDHRA PRADESH                                  188511                  2548
# ARUNACHAL PRADESH                                  705                     7
# ASSAM                                           135415                   343
# BIHAR                                            55187                   825
# CHANDIGARH                                        1689                     7
# CHHATTISGARH                                     16381                   103
# D & N HAVELI                                      7349                    12
# DAMAN & DIU                                        912                    29
# DELHI                                            27119                   103
# GOA                                                356                   111
# GUJARAT                                          96480                   493
# HARYANA                                          63266                   519
# HIMACHAL PRADESH                                  5420                    64
# JAMMU & KASHMIR                                   6274                    13
# JHARKHAND                                        22458                   554
# KARNATAKA                                        56202                  2799
# KERALA                                           84277                   990
# LAKSHADWEEP                                         17                     0
# MADHYA PRADESH                                   95521                   396
# MAHARASHTRA                                     133357                  2533
# MANIPUR                                            443                    18
# MEGHALAYA                                          379                    24
# MIZORAM                                            130                    14
# NAGALAND                                          8577                    66
# ODISHA                                           41222                   270
# PUDUCHERRY                                         178                    13
# PUNJAB                                           53549                   600
# RAJASTHAN                                       201488                   668
# SIKKIM                                            1629                   613
# TAMIL NADU                                       45393                  4041
# TELANGANA                                        44276                   866
# TRIPURA                                          42905                    43
# UTTAR PRADESH                                   163062                   333
# UTTARAKHAND                                      47251                   188
# WEST BENGAL                                     262235                   940
#
#                     Total
# State
# A & N ISLANDS        9717
# ANDHRA PRADESH     398373
# ARUNACHAL PRADESH   12093
# ASSAM              299272
# BIHAR              197199
# CHANDIGARH          13211
# CHHATTISGARH       105021
# D & N HAVELI        29816
# DAMAN & DIU         14927
# DELHI              110812
# GOA                 11534
# GUJARAT            161715
# HARYANA            159876
# HIMACHAL PRADESH    30375
# JAMMU & KASHMIR     67610
# JHARKHAND           90287
# KARNATAKA          168845
# KERALA             210488
# LAKSHADWEEP          8016
# MADHYA PRADESH     420680
# MAHARASHTRA        373176
# MANIPUR             11955
# MEGHALAYA           11880
# MIZORAM             10451
# NAGALAND            58221
# ODISHA             202423
# PUDUCHERRY           9758
# PUNJAB             143245
# RAJASTHAN          386955
# SIKKIM              15166
# TAMIL NADU         141617
# TELANGANA           93105
# TRIPURA            109950
# UTTAR PRADESH      537520
# UTTARAKHAND         95843
# WEST BENGAL        417070

# %%
#sorting the statewise crime from highest to lowest
state_all_crimes.sort_values('Total',ascending=False)
state_all_crimes
# Out:
#                    Unnamed: 0   Rape  Kidnapping and Abduction  Dowry Deaths  \
# State
# A & N ISLANDS            7849    424                       363            13
# ANDHRA PRADESH           7250  23424                     21707          8165
# ARUNACHAL PRADESH        7271   1153                      1272             4
# ASSAM                    7292  32190                     71462          2757
# BIHAR                    7313  21006                     77687         24428
# CHANDIGARH               7870    795                      1547            68
# CHHATTISGARH             7334  25178                     16536          1797
# D & N HAVELI             7891   2343                      7148           256
# DAMAN & DIU              7912    619                      1725            30
# DELHI                    6083  13065                     31251          1106
# GOA                      7355   1019                       720            23
# GUJARAT                  7376   9940                     25733           652
# HARYANA                  7397  17776                     29593          5144
# HIMACHAL PRADESH         7418   4474                      4043            76
# JAMMU & KASHMIR          7439   7656                     17464           735
# JHARKHAND                7460  18054                     13604          6814
# KARNATAKA                7481  12723                     15258          6028
# KERALA                   7502  24184                     14056          1525
# LAKSHADWEEP              7944     20                         1             0
# MADHYA PRADESH           7523  72808                     57485         13316
# MAHARASHTRA              7544  39252                     46522          5756
# MANIPUR                  7565    905                      1802             3
# MEGHALAYA                7586   1971                       628            24
# MIZORAM                  7607   1241                        40             5
# NAGALAND                 7628   3037                      9180           615
# ODISHA                   7649  24810                     29847          7521
# PUDUCHERRY               7965    140                       201            48
# PUNJAB                   7670  23062                     24611          2977
# RAJASTHAN                7691  43799                     55320          7769
# SIKKIM                   7712   1237                      1428            71
# TAMIL NADU               7733  11633                     23534          3314
# TELANGANA                5984   5533                      5948          1724
# TRIPURA                  7765   8844                     21390          4976
# UTTAR PRADESH            7786  45694                    133856         40615
# UTTARAKHAND              7807   6207                     20319          2320
# WEST BENGAL              7828  29486                     51742          8075
#
#                    Assault on women with intent to outrage her modesty  \
# State
# A & N ISLANDS                                                    558
# ANDHRA PRADESH                                                 92084
# ARUNACHAL PRADESH                                               1584
# ASSAM                                                          47115
# BIHAR                                                           9953
# CHANDIGARH                                                       954
# CHHATTISGARH                                                   33310
# D & N HAVELI                                                    3977
# DAMAN & DIU                                                     3642
# DELHI                                                          26039
# GOA                                                             1475
# GUJARAT                                                        18116
# HARYANA                                                        24347
# HIMACHAL PRADESH                                                7574
# JAMMU & KASHMIR                                                22850
# JHARKHAND                                                      19771
# KARNATAKA                                                      64492
# KERALA                                                         69081
# LAKSHADWEEP                                                       23
# MADHYA PRADESH                                                152000
# MAHARASHTRA                                                   107519
# MANIPUR                                                         1131
# MEGHALAYA                                                       1160
# MIZORAM                                                         1252
# NAGALAND                                                       27631
# ODISHA                                                         83473
# PUDUCHERRY                                                       870
# PUNJAB                                                         28644
# RAJASTHAN                                                      67855
# SIKKIM                                                          2358
# TAMIL NADU                                                     33885
# TELANGANA                                                      23938
# TRIPURA                                                        23744
# UTTAR PRADESH                                                  99650
# UTTARAKHAND                                                     9160
# WEST BENGAL                                                    51014
#
#                    Insult to modesty of Women  \
# State
# A & N ISLANDS                             135
# ANDHRA PRADESH                          54684
# ARUNACHAL PRADESH                          97
# ASSAM                                    2698
# BIHAR                                     800
# CHANDIGARH                                281
# CHHATTISGARH                             4382
# D & N HAVELI                              840
# DAMAN & DIU                                58
# DELHI                                    6046
# GOA                                       475
# GUJARAT                                  2925
# HARYANA                                 11834
# HIMACHAL PRADESH                         1306
# JAMMU & KASHMIR                          5179
# JHARKHAND                                1572
# KARNATAKA                                3862
# KERALA                                   8873
# LAKSHADWEEP                                11
# MADHYA PRADESH                          21631
# MAHARASHTRA                             30693
# MANIPUR                                    88
# MEGHALAYA                                 108
# MIZORAM                                   162
# NAGALAND                                 1487
# ODISHA                                   7631
# PUDUCHERRY                                343
# PUNJAB                                   2132
# RAJASTHAN                                2365
# SIKKIM                                    118
# TAMIL NADU                              12084
# TELANGANA                                4836
# TRIPURA                                   283
# UTTAR PRADESH                           46524
# UTTARAKHAND                              2591
# WEST BENGAL                              5750
#
#                    Cruelty by Husband or his Relatives  Importation of Girls  \
# State
# A & N ISLANDS                                      365                    10
# ANDHRA PRADESH                                  188511                  2548
# ARUNACHAL PRADESH                                  705                     7
# ASSAM                                           135415                   343
# BIHAR                                            55187                   825
# CHANDIGARH                                        1689                     7
# CHHATTISGARH                                     16381                   103
# D & N HAVELI                                      7349                    12
# DAMAN & DIU                                        912                    29
# DELHI                                            27119                   103
# GOA                                                356                   111
# GUJARAT                                          96480                   493
# HARYANA                                          63266                   519
# HIMACHAL PRADESH                                  5420                    64
# JAMMU & KASHMIR                                   6274                    13
# JHARKHAND                                        22458                   554
# KARNATAKA                                        56202                  2799
# KERALA                                           84277                   990
# LAKSHADWEEP                                         17                     0
# MADHYA PRADESH                                   95521                   396
# MAHARASHTRA                                     133357                  2533
# MANIPUR                                            443                    18
# MEGHALAYA                                          379                    24
# MIZORAM                                            130                    14
# NAGALAND                                          8577                    66
# ODISHA                                           41222                   270
# PUDUCHERRY                                         178                    13
# PUNJAB                                           53549                   600
# RAJASTHAN                                       201488                   668
# SIKKIM                                            1629                   613
# TAMIL NADU                                       45393                  4041
# TELANGANA                                        44276                   866
# TRIPURA                                          42905                    43
# UTTAR PRADESH                                   163062                   333
# UTTARAKHAND                                      47251                   188
# WEST BENGAL                                     262235                   940
#
#                     Total
# State
# A & N ISLANDS        9717
# ANDHRA PRADESH     398373
# ARUNACHAL PRADESH   12093
# ASSAM              299272
# BIHAR              197199
# CHANDIGARH          13211
# CHHATTISGARH       105021
# D & N HAVELI        29816
# DAMAN & DIU         14927
# DELHI              110812
# GOA                 11534
# GUJARAT            161715
# HARYANA            159876
# HIMACHAL PRADESH    30375
# JAMMU & KASHMIR     67610
# JHARKHAND           90287
# KARNATAKA          168845
# KERALA             210488
# LAKSHADWEEP          8016
# MADHYA PRADESH     420680
# MAHARASHTRA        373176
# MANIPUR             11955
# MEGHALAYA           11880
# MIZORAM             10451
# NAGALAND            58221
# ODISHA             202423
# PUDUCHERRY           9758
# PUNJAB             143245
# RAJASTHAN          386955
# SIKKIM              15166
# TAMIL NADU         141617
# TELANGANA           93105
# TRIPURA            109950
# UTTAR PRADESH      537520
# UTTARAKHAND         95843
# WEST BENGAL        417070

# %%
# Exploratory Data Analysis (EDA)
# 1. Aggregate state-level data for overall analysis
state_all_crimes = df.groupby('State').sum()
state_all_crimes.drop('Year', axis=1, inplace=True)
state_all_crimes['Total'] = state_all_crimes.sum(axis=1)

# %%
# Fixing and grouping the data by state
state_all_crimes = df.groupby('State').sum(numeric_only=True)  # Ensure only numeric columns are summed
state_all_crimes['Total'] = state_all_crimes.sum(axis=1)

# Sorting states by total crimes
top_states = state_all_crimes.sort_values('Total', ascending=False).head(10)

# Plotting the data
plt.figure(figsize=(12, 6))
top_states.drop(columns=['Total']).plot(kind='bar', stacked=True, ax=plt.gca())  # Exclude 'Total' from the plot
plt.title('Top 10 States with the Highest Number of Crimes Against Women')
plt.xlabel('State')
plt.ylabel('Number of Crimes')
plt.xticks(ticks=range(len(top_states)), labels=top_states.index, rotation=45)
plt.legend(title="Crime Types")
plt.tight_layout()
plt.show()

# %%
# 3. Correlation Matrix
correlation_matrix = df.drop(['State', 'Year'], axis=1).corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Different Crimes')
plt.show()

# %%
def plot_overall_crime_trend():
    sns.set(style="whitegrid")


    # Aggregate by year for overall trend
    overall_trend = statewise_data.groupby('Year')[crime_types].sum().reset_index()


    # Plot each crime type over the years
    plt.figure(figsize=(14, 8))
    for crime in crime_types:
        plt.plot(overall_trend['Year'], overall_trend[crime], label=crime)


    plt.title('Overall Crime Trend in India (2001-2021)')
    plt.xlabel('Year')
    plt.ylabel('Number of Cases')
    plt.legend(loc='upper left')
    plt.show()
plot_overall_crime_trend()

# %%
# Step 4: Holt-Winters Forecasting for All Crime Types (Forecast for a Specific Year for All States)
def holt_winters_forecasting_all_states(forecast_year):
    all_forecasted_results = {}

    # Get unique list of states in original order
    states = df['State'].unique()

    # Forecasting for each state and each crime type
    for state in states:
        forecasted_results = {}

        for crime_type in crime_types:
            # Filter data for the selected state and crime type
            state_data = statewise_data[statewise_data['State'] == state][['Year', crime_type]].set_index('Year')

            # Check if state_data is empty
            if state_data.empty:
                forecasted_results[crime_type] = "No data available"
                continue

            # Convert the 'Year' index to a proper DatetimeIndex with explicit frequency
            state_data.index = pd.to_datetime(state_data.index, format='%Y')
            state_data.index.freq = 'YS'  # Set frequency explicitly to Year Start

            # Fit the Holt-Winters model (Additive trend)
            model = ExponentialSmoothing(state_data[crime_type], trend='add', seasonal=None, seasonal_periods=4).fit()

            # Forecast for the given number of years into the future
            last_year = state_data.index.year.max()
            forecast_period = forecast_year - last_year
            forecast = model.forecast(forecast_period)

            # Generate future year index using 'YE' (year-end frequency)
            forecast_years = pd.date_range(start=str(last_year + 1), periods=forecast_period, freq='YE').year

            # Filter forecast for the specified year only
            if forecast_year in forecast_years:
                forecasted_results[crime_type] = round(forecast[forecast_years == forecast_year].values[0])  # Round to nearest integer
            else:
                forecasted_results[crime_type] = "Forecast not possible"

        # Store forecasts for each state
        all_forecasted_results[state] = forecasted_results

    return all_forecasted_results

# Step 5: User Input and Forecasting for All States
def forecast_crimes_for_all_states():
    forecast_year = int(input("Enter the year you want to forecast (e.g., 2025): "))

    # Forecast all crime types for all states for the specified year
    forecasts = holt_winters_forecasting_all_states(forecast_year)

    print(f"\nForecasted crime rates for all states for the year {forecast_year}:\n")
    for state, forecasted_results in forecasts.items():
        print(f"{state}:")
        for crime_type, forecast in forecasted_results.items():
            print(f"  {crime_type}: {forecast}")
        print("\n")

# Call the function
forecast_crimes_for_all_states()
# Out:
# Enter the year you want to forecast (e.g., 2025): 2025
#
# Forecasted crime rates for all states for the year 2025:
#
# ANDHRA PRADESH:
#   Rape: 1962
#   Kidnapping and Abduction: 3066
#   Dowry Deaths: 868
#   Assault on women with intent to outrage her modesty: 7183
#   Insult to modesty of Women: 7643
#   Cruelty by Husband or his Relatives: 21817
#
#
# ARUNACHAL PRADESH:
#   Rape: 82
#   Kidnapping and Abduction: 26
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 85
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 19
#
#
# ASSAM:
#   Rape: 3082
#   Kidnapping and Abduction: 11682
#   Dowry Deaths: 343
#   Assault on women with intent to outrage her modesty: 2186
#   Insult to modesty of Women: 26
#   Cruelty by Husband or his Relatives: 20405
#
#
# BIHAR:
#   Rape: 1191
#   Kidnapping and Abduction: 5991
#   Dowry Deaths: 2063
#   Assault on women with intent to outrage her modesty: 970
#   Insult to modesty of Women: 28
#   Cruelty by Husband or his Relatives: 3197
#
#
# CHHATTISGARH:
#   Rape: 1071
#   Kidnapping and Abduction: 410
#   Dowry Deaths: 206
#   Assault on women with intent to outrage her modesty: 1684
#   Insult to modesty of Women: 171
#   Cruelty by Husband or his Relatives: 1199
#
#
# GOA:
#   Rape: 75
#   Kidnapping and Abduction: 47
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 66
#   Insult to modesty of Women: 22
#   Cruelty by Husband or his Relatives: 24
#
#
# GUJARAT:
#   Rape: 678
#   Kidnapping and Abduction: 1971
#   Dowry Deaths: -59
#   Assault on women with intent to outrage her modesty: 722
#   Insult to modesty of Women: 131
#   Cruelty by Husband or his Relatives: 10702
#
#
# HARYANA:
#   Rape: 1261
#   Kidnapping and Abduction: 1407
#   Dowry Deaths: 340
#   Assault on women with intent to outrage her modesty: 499
#   Insult to modesty of Women: -341
#   Cruelty by Husband or his Relatives: 4918
#
#
# HIMACHAL PRADESH:
#   Rape: 239
#   Kidnapping and Abduction: 229
#   Dowry Deaths: -9
#   Assault on women with intent to outrage her modesty: 376
#   Insult to modesty of Women: 140
#   Cruelty by Husband or his Relatives: 380
#
#
# JAMMU & KASHMIR:
#   Rape: 376
#   Kidnapping and Abduction: 1281
#   Dowry Deaths: 9
#   Assault on women with intent to outrage her modesty: 1546
#   Insult to modesty of Women: 286
#   Cruelty by Husband or his Relatives: 504
#
#
# JHARKHAND:
#   Rape: 984
#   Kidnapping and Abduction: 1389
#   Dowry Deaths: 365
#   Assault on women with intent to outrage her modesty: 71
#   Insult to modesty of Women: 118
#   Cruelty by Husband or his Relatives: 1184
#
#
# KARNATAKA:
#   Rape: 1015
#   Kidnapping and Abduction: 911
#   Dowry Deaths: 332
#   Assault on women with intent to outrage her modesty: 4101
#   Insult to modesty of Women: 86
#   Cruelty by Husband or his Relatives: 6714
#
#
# KERALA:
#   Rape: 792
#   Kidnapping and Abduction: 366
#   Dowry Deaths: 20
#   Assault on women with intent to outrage her modesty: 4427
#   Insult to modesty of Women: 1114
#   Cruelty by Husband or his Relatives: 7935
#
#
# MADHYA PRADESH:
#   Rape: 3479
#   Kidnapping and Abduction: 1633
#   Dowry Deaths: 1294
#   Assault on women with intent to outrage her modesty: 5311
#   Insult to modesty of Women: 930
#   Cruelty by Husband or his Relatives: 5307
#
#
# MAHARASHTRA:
#   Rape: 2057
#   Kidnapping and Abduction: 1912
#   Dowry Deaths: 542
#   Assault on women with intent to outrage her modesty: 5226
#   Insult to modesty of Women: 1623
#   Cruelty by Husband or his Relatives: 12007
#
#
# MANIPUR:
#   Rape: 66
#   Kidnapping and Abduction: 156
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 60
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 58
#
#
# MEGHALAYA:
#   Rape: 704
#   Kidnapping and Abduction: 72
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 136
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 77
#
#
# MIZORAM:
#   Rape: 153
#   Kidnapping and Abduction: -2
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 75
#   Insult to modesty of Women: 1
#   Cruelty by Husband or his Relatives: -7
#
#
# NAGALAND:
#   Rape: 23
#   Kidnapping and Abduction: 13
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 31
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 5
#
#
# ODISHA:
#   Rape: 1722
#   Kidnapping and Abduction: 1721
#   Dowry Deaths: 706
#   Assault on women with intent to outrage her modesty: 5509
#   Insult to modesty of Women: 106
#   Cruelty by Husband or his Relatives: 2880
#
#
# PUNJAB:
#   Rape: 1001
#   Kidnapping and Abduction: 1040
#   Dowry Deaths: 76
#   Assault on women with intent to outrage her modesty: 384
#   Insult to modesty of Women: -115
#   Cruelty by Husband or his Relatives: 1251
#
#
# RAJASTHAN:
#   Rape: 2420
#   Kidnapping and Abduction: 3546
#   Dowry Deaths: 584
#   Assault on women with intent to outrage her modesty: 1600
#   Insult to modesty of Women: -31
#   Cruelty by Husband or his Relatives: 19321
#
#
# SIKKIM:
#   Rape: 49
#   Kidnapping and Abduction: 16
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 9
#   Insult to modesty of Women: -13
#   Cruelty by Husband or his Relatives: 14
#
#
# TAMIL NADU:
#   Rape: 847
#   Kidnapping and Abduction: 2606
#   Dowry Deaths: 120
#   Assault on women with intent to outrage her modesty: 350
#   Insult to modesty of Women: -481
#   Cruelty by Husband or his Relatives: 2780
#
#
# TRIPURA:
#   Rape: 430
#   Kidnapping and Abduction: 220
#   Dowry Deaths: 48
#   Assault on women with intent to outrage her modesty: 940
#   Insult to modesty of Women: 20
#   Cruelty by Husband or his Relatives: 2108
#
#
# UTTAR PRADESH:
#   Rape: 2037
#   Kidnapping and Abduction: 10410
#   Dowry Deaths: 2911
#   Assault on women with intent to outrage her modesty: 4091
#   Insult to modesty of Women: -442
#   Cruelty by Husband or his Relatives: 13724
#
#
# UTTARAKHAND:
#   Rape: 169
#   Kidnapping and Abduction: 481
#   Dowry Deaths: 105
#   Assault on women with intent to outrage her modesty: 129
#   Insult to modesty of Women: 458
#   Cruelty by Husband or his Relatives: 463
#
#
# WEST BENGAL:
#   Rape: 5620
#   Kidnapping and Abduction: 9605
#   Dowry Deaths: 910
#   Assault on women with intent to outrage her modesty: 5132
#   Insult to modesty of Women: 290
#   Cruelty by Husband or his Relatives: 43145
#
#
# A & N ISLANDS:
#   Rape: 48
#   Kidnapping and Abduction: 32
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 51
#   Insult to modesty of Women: 17
#   Cruelty by Husband or his Relatives: 41
#
#
# CHANDIGARH:
#   Rape: 46
#   Kidnapping and Abduction: 20
#   Dowry Deaths: 7
#   Assault on women with intent to outrage her modesty: 30
#   Insult to modesty of Women: -26
#   Cruelty by Husband or his Relatives: 61
#
#
# D & N HAVELI:
#   Rape: 5
#   Kidnapping and Abduction: 24
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 6
#   Insult to modesty of Women: 3
#   Cruelty by Husband or his Relatives: 4
#
#
# DAMAN & DIU:
#   Rape: 0
#   Kidnapping and Abduction: -1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 6
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 4
#
#
# LAKSHADWEEP:
#   Rape: 1
#   Kidnapping and Abduction: 1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 0
#   Insult to modesty of Women: 0
#   Cruelty by Husband or his Relatives: 1
#
#
# PUDUCHERRY:
#   Rape: 1
#   Kidnapping and Abduction: 28
#   Dowry Deaths: -3
#   Assault on women with intent to outrage her modesty: 82
#   Insult to modesty of Women: 12
#   Cruelty by Husband or his Relatives: 26
#
#
# TELANGANA:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available
#
#
# DELHI:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available

# %%
forecast_crimes_for_all_states()
# Out:
# Enter the year you want to forecast (e.g., 2025): 2026
#
# Forecasted crime rates for all states for the year 2026:
#
# ANDHRA PRADESH:
#   Rape: 2008
#   Kidnapping and Abduction: 3162
#   Dowry Deaths: 886
#   Assault on women with intent to outrage her modesty: 7335
#   Insult to modesty of Women: 7887
#   Cruelty by Husband or his Relatives: 22463
#
#
# ARUNACHAL PRADESH:
#   Rape: 84
#   Kidnapping and Abduction: 25
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 86
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 19
#
#
# ASSAM:
#   Rape: 3175
#   Kidnapping and Abduction: 12279
#   Dowry Deaths: 355
#   Assault on women with intent to outrage her modesty: 2243
#   Insult to modesty of Women: 26
#   Cruelty by Husband or his Relatives: 21406
#
#
# BIHAR:
#   Rape: 1195
#   Kidnapping and Abduction: 6223
#   Dowry Deaths: 2113
#   Assault on women with intent to outrage her modesty: 985
#   Insult to modesty of Women: 28
#   Cruelty by Husband or his Relatives: 3261
#
#
# CHHATTISGARH:
#   Rape: 1076
#   Kidnapping and Abduction: 421
#   Dowry Deaths: 211
#   Assault on women with intent to outrage her modesty: 1689
#   Insult to modesty of Women: 173
#   Cruelty by Husband or his Relatives: 1221
#
#
# GOA:
#   Rape: 77
#   Kidnapping and Abduction: 49
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 68
#   Insult to modesty of Women: 23
#   Cruelty by Husband or his Relatives: 25
#
#
# GUJARAT:
#   Rape: 695
#   Kidnapping and Abduction: 2021
#   Dowry Deaths: -64
#   Assault on women with intent to outrage her modesty: 720
#   Insult to modesty of Women: 132
#   Cruelty by Husband or his Relatives: 11012
#
#
# HARYANA:
#   Rape: 1300
#   Kidnapping and Abduction: 1453
#   Dowry Deaths: 344
#   Assault on women with intent to outrage her modesty: 502
#   Insult to modesty of Women: -396
#   Cruelty by Husband or his Relatives: 5062
#
#
# HIMACHAL PRADESH:
#   Rape: 244
#   Kidnapping and Abduction: 234
#   Dowry Deaths: -10
#   Assault on women with intent to outrage her modesty: 380
#   Insult to modesty of Women: 145
#   Cruelty by Husband or his Relatives: 385
#
#
# JAMMU & KASHMIR:
#   Rape: 384
#   Kidnapping and Abduction: 1312
#   Dowry Deaths: 9
#   Assault on women with intent to outrage her modesty: 1579
#   Insult to modesty of Women: 284
#   Cruelty by Husband or his Relatives: 524
#
#
# JHARKHAND:
#   Rape: 995
#   Kidnapping and Abduction: 1440
#   Dowry Deaths: 370
#   Assault on women with intent to outrage her modesty: 57
#   Insult to modesty of Women: 123
#   Cruelty by Husband or his Relatives: 1211
#
#
# KARNATAKA:
#   Rape: 1047
#   Kidnapping and Abduction: 940
#   Dowry Deaths: 337
#   Assault on women with intent to outrage her modesty: 4205
#   Insult to modesty of Women: 87
#   Cruelty by Husband or his Relatives: 6932
#
#
# KERALA:
#   Rape: 805
#   Kidnapping and Abduction: 377
#   Dowry Deaths: 20
#   Assault on women with intent to outrage her modesty: 4531
#   Insult to modesty of Women: 1160
#   Cruelty by Husband or his Relatives: 8160
#
#
# MADHYA PRADESH:
#   Rape: 3508
#   Kidnapping and Abduction: 1673
#   Dowry Deaths: 1322
#   Assault on women with intent to outrage her modesty: 5242
#   Insult to modesty of Women: 937
#   Cruelty by Husband or his Relatives: 5414
#
#
# MAHARASHTRA:
#   Rape: 2089
#   Kidnapping and Abduction: 1967
#   Dowry Deaths: 551
#   Assault on women with intent to outrage her modesty: 5333
#   Insult to modesty of Women: 1657
#   Cruelty by Husband or his Relatives: 12285
#
#
# MANIPUR:
#   Rape: 68
#   Kidnapping and Abduction: 160
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 61
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 60
#
#
# MEGHALAYA:
#   Rape: 741
#   Kidnapping and Abduction: 75
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 141
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 80
#
#
# MIZORAM:
#   Rape: 158
#   Kidnapping and Abduction: -3
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 75
#   Insult to modesty of Women: 1
#   Cruelty by Husband or his Relatives: -8
#
#
# NAGALAND:
#   Rape: 23
#   Kidnapping and Abduction: 14
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 32
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 5
#
#
# ODISHA:
#   Rape: 1765
#   Kidnapping and Abduction: 1779
#   Dowry Deaths: 724
#   Assault on women with intent to outrage her modesty: 5675
#   Insult to modesty of Women: 99
#   Cruelty by Husband or his Relatives: 2958
#
#
# PUNJAB:
#   Rape: 1030
#   Kidnapping and Abduction: 1072
#   Dowry Deaths: 74
#   Assault on women with intent to outrage her modesty: 386
#   Insult to modesty of Women: -125
#   Cruelty by Husband or his Relatives: 1257
#
#
# RAJASTHAN:
#   Rape: 2477
#   Kidnapping and Abduction: 3618
#   Dowry Deaths: 593
#   Assault on women with intent to outrage her modesty: 1549
#   Insult to modesty of Women: -35
#   Cruelty by Husband or his Relatives: 19929
#
#
# SIKKIM:
#   Rape: 50
#   Kidnapping and Abduction: 17
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 8
#   Insult to modesty of Women: -14
#   Cruelty by Husband or his Relatives: 15
#
#
# TAMIL NADU:
#   Rape: 862
#   Kidnapping and Abduction: 2694
#   Dowry Deaths: 116
#   Assault on women with intent to outrage her modesty: 284
#   Insult to modesty of Women: -553
#   Cruelty by Husband or his Relatives: 2849
#
#
# TRIPURA:
#   Rape: 444
#   Kidnapping and Abduction: 228
#   Dowry Deaths: 50
#   Assault on women with intent to outrage her modesty: 977
#   Insult to modesty of Women: 21
#   Cruelty by Husband or his Relatives: 2190
#
#
# UTTAR PRADESH:
#   Rape: 2065
#   Kidnapping and Abduction: 10779
#   Dowry Deaths: 2962
#   Assault on women with intent to outrage her modesty: 4183
#   Insult to modesty of Women: -601
#   Cruelty by Husband or his Relatives: 14105
#
#
# UTTARAKHAND:
#   Rape: 172
#   Kidnapping and Abduction: 496
#   Dowry Deaths: 106
#   Assault on women with intent to outrage her modesty: 129
#   Insult to modesty of Women: 475
#   Cruelty by Husband or his Relatives: 469
#
#
# WEST BENGAL:
#   Rape: 5825
#   Kidnapping and Abduction: 10065
#   Dowry Deaths: 937
#   Assault on women with intent to outrage her modesty: 5308
#   Insult to modesty of Women: 301
#   Cruelty by Husband or his Relatives: 44835
#
#
# A & N ISLANDS:
#   Rape: 50
#   Kidnapping and Abduction: 33
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 52
#   Insult to modesty of Women: 18
#   Cruelty by Husband or his Relatives: 43
#
#
# CHANDIGARH:
#   Rape: 47
#   Kidnapping and Abduction: 19
#   Dowry Deaths: 7
#   Assault on women with intent to outrage her modesty: 30
#   Insult to modesty of Women: -28
#   Cruelty by Husband or his Relatives: 61
#
#
# D & N HAVELI:
#   Rape: 5
#   Kidnapping and Abduction: 25
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 6
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 4
#
#
# DAMAN & DIU:
#   Rape: 0
#   Kidnapping and Abduction: -1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 6
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 4
#
#
# LAKSHADWEEP:
#   Rape: 1
#   Kidnapping and Abduction: 1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 0
#   Insult to modesty of Women: 0
#   Cruelty by Husband or his Relatives: 1
#
#
# PUDUCHERRY:
#   Rape: 1
#   Kidnapping and Abduction: 29
#   Dowry Deaths: -3
#   Assault on women with intent to outrage her modesty: 84
#   Insult to modesty of Women: 11
#   Cruelty by Husband or his Relatives: 26
#
#
# TELANGANA:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available
#
#
# DELHI:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available

# %%
forecast_crimes_for_all_states()
# Out:
# Enter the year you want to forecast (e.g., 2025): 2027
#
# Forecasted crime rates for all states for the year 2027:
#
# ANDHRA PRADESH:
#   Rape: 2054
#   Kidnapping and Abduction: 3259
#   Dowry Deaths: 905
#   Assault on women with intent to outrage her modesty: 7486
#   Insult to modesty of Women: 8132
#   Cruelty by Husband or his Relatives: 23109
#
#
# ARUNACHAL PRADESH:
#   Rape: 87
#   Kidnapping and Abduction: 24
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 87
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 20
#
#
# ASSAM:
#   Rape: 3267
#   Kidnapping and Abduction: 12876
#   Dowry Deaths: 368
#   Assault on women with intent to outrage her modesty: 2301
#   Insult to modesty of Women: 27
#   Cruelty by Husband or his Relatives: 22406
#
#
# BIHAR:
#   Rape: 1198
#   Kidnapping and Abduction: 6454
#   Dowry Deaths: 2163
#   Assault on women with intent to outrage her modesty: 1001
#   Insult to modesty of Women: 29
#   Cruelty by Husband or his Relatives: 3326
#
#
# CHHATTISGARH:
#   Rape: 1080
#   Kidnapping and Abduction: 432
#   Dowry Deaths: 217
#   Assault on women with intent to outrage her modesty: 1694
#   Insult to modesty of Women: 175
#   Cruelty by Husband or his Relatives: 1243
#
#
# GOA:
#   Rape: 80
#   Kidnapping and Abduction: 51
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 70
#   Insult to modesty of Women: 24
#   Cruelty by Husband or his Relatives: 25
#
#
# GUJARAT:
#   Rape: 713
#   Kidnapping and Abduction: 2072
#   Dowry Deaths: -69
#   Assault on women with intent to outrage her modesty: 719
#   Insult to modesty of Women: 133
#   Cruelty by Husband or his Relatives: 11321
#
#
# HARYANA:
#   Rape: 1339
#   Kidnapping and Abduction: 1499
#   Dowry Deaths: 348
#   Assault on women with intent to outrage her modesty: 506
#   Insult to modesty of Women: -451
#   Cruelty by Husband or his Relatives: 5205
#
#
# HIMACHAL PRADESH:
#   Rape: 248
#   Kidnapping and Abduction: 240
#   Dowry Deaths: -11
#   Assault on women with intent to outrage her modesty: 384
#   Insult to modesty of Women: 151
#   Cruelty by Husband or his Relatives: 391
#
#
# JAMMU & KASHMIR:
#   Rape: 392
#   Kidnapping and Abduction: 1343
#   Dowry Deaths: 9
#   Assault on women with intent to outrage her modesty: 1612
#   Insult to modesty of Women: 281
#   Cruelty by Husband or his Relatives: 543
#
#
# JHARKHAND:
#   Rape: 1007
#   Kidnapping and Abduction: 1492
#   Dowry Deaths: 375
#   Assault on women with intent to outrage her modesty: 43
#   Insult to modesty of Women: 128
#   Cruelty by Husband or his Relatives: 1239
#
#
# KARNATAKA:
#   Rape: 1079
#   Kidnapping and Abduction: 969
#   Dowry Deaths: 341
#   Assault on women with intent to outrage her modesty: 4309
#   Insult to modesty of Women: 87
#   Cruelty by Husband or his Relatives: 7151
#
#
# KERALA:
#   Rape: 819
#   Kidnapping and Abduction: 388
#   Dowry Deaths: 20
#   Assault on women with intent to outrage her modesty: 4635
#   Insult to modesty of Women: 1206
#   Cruelty by Husband or his Relatives: 8385
#
#
# MADHYA PRADESH:
#   Rape: 3536
#   Kidnapping and Abduction: 1713
#   Dowry Deaths: 1350
#   Assault on women with intent to outrage her modesty: 5173
#   Insult to modesty of Women: 945
#   Cruelty by Husband or his Relatives: 5520
#
#
# MAHARASHTRA:
#   Rape: 2120
#   Kidnapping and Abduction: 2021
#   Dowry Deaths: 560
#   Assault on women with intent to outrage her modesty: 5439
#   Insult to modesty of Women: 1690
#   Cruelty by Husband or his Relatives: 12563
#
#
# MANIPUR:
#   Rape: 70
#   Kidnapping and Abduction: 164
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 62
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 62
#
#
# MEGHALAYA:
#   Rape: 778
#   Kidnapping and Abduction: 78
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 146
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 83
#
#
# MIZORAM:
#   Rape: 162
#   Kidnapping and Abduction: -3
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 76
#   Insult to modesty of Women: 1
#   Cruelty by Husband or his Relatives: -8
#
#
# NAGALAND:
#   Rape: 23
#   Kidnapping and Abduction: 14
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 33
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 5
#
#
# ODISHA:
#   Rape: 1808
#   Kidnapping and Abduction: 1837
#   Dowry Deaths: 742
#   Assault on women with intent to outrage her modesty: 5842
#   Insult to modesty of Women: 92
#   Cruelty by Husband or his Relatives: 3035
#
#
# PUNJAB:
#   Rape: 1060
#   Kidnapping and Abduction: 1104
#   Dowry Deaths: 71
#   Assault on women with intent to outrage her modesty: 388
#   Insult to modesty of Women: -134
#   Cruelty by Husband or his Relatives: 1263
#
#
# RAJASTHAN:
#   Rape: 2533
#   Kidnapping and Abduction: 3689
#   Dowry Deaths: 602
#   Assault on women with intent to outrage her modesty: 1497
#   Insult to modesty of Women: -38
#   Cruelty by Husband or his Relatives: 20538
#
#
# SIKKIM:
#   Rape: 52
#   Kidnapping and Abduction: 18
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 8
#   Insult to modesty of Women: -15
#   Cruelty by Husband or his Relatives: 15
#
#
# TAMIL NADU:
#   Rape: 877
#   Kidnapping and Abduction: 2781
#   Dowry Deaths: 112
#   Assault on women with intent to outrage her modesty: 218
#   Insult to modesty of Women: -625
#   Cruelty by Husband or his Relatives: 2918
#
#
# TRIPURA:
#   Rape: 458
#   Kidnapping and Abduction: 236
#   Dowry Deaths: 51
#   Assault on women with intent to outrage her modesty: 1015
#   Insult to modesty of Women: 21
#   Cruelty by Husband or his Relatives: 2273
#
#
# UTTAR PRADESH:
#   Rape: 2092
#   Kidnapping and Abduction: 11147
#   Dowry Deaths: 3013
#   Assault on women with intent to outrage her modesty: 4275
#   Insult to modesty of Women: -759
#   Cruelty by Husband or his Relatives: 14487
#
#
# UTTARAKHAND:
#   Rape: 175
#   Kidnapping and Abduction: 512
#   Dowry Deaths: 108
#   Assault on women with intent to outrage her modesty: 129
#   Insult to modesty of Women: 491
#   Cruelty by Husband or his Relatives: 475
#
#
# WEST BENGAL:
#   Rape: 6029
#   Kidnapping and Abduction: 10526
#   Dowry Deaths: 964
#   Assault on women with intent to outrage her modesty: 5483
#   Insult to modesty of Women: 312
#   Cruelty by Husband or his Relatives: 46525
#
#
# A & N ISLANDS:
#   Rape: 52
#   Kidnapping and Abduction: 35
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 54
#   Insult to modesty of Women: 18
#   Cruelty by Husband or his Relatives: 44
#
#
# CHANDIGARH:
#   Rape: 49
#   Kidnapping and Abduction: 18
#   Dowry Deaths: 7
#   Assault on women with intent to outrage her modesty: 30
#   Insult to modesty of Women: -30
#   Cruelty by Husband or his Relatives: 60
#
#
# D & N HAVELI:
#   Rape: 5
#   Kidnapping and Abduction: 26
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 6
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 4
#
#
# DAMAN & DIU:
#   Rape: 0
#   Kidnapping and Abduction: -1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 5
#
#
# LAKSHADWEEP:
#   Rape: 1
#   Kidnapping and Abduction: 1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 0
#   Insult to modesty of Women: 0
#   Cruelty by Husband or his Relatives: 1
#
#
# PUDUCHERRY:
#   Rape: 0
#   Kidnapping and Abduction: 30
#   Dowry Deaths: -3
#   Assault on women with intent to outrage her modesty: 85
#   Insult to modesty of Women: 10
#   Cruelty by Husband or his Relatives: 27
#
#
# TELANGANA:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available
#
#
# DELHI:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available

# %%
forecast_crimes_for_all_states()
# Out:
# Enter the year you want to forecast (e.g., 2025): 2028
#
# Forecasted crime rates for all states for the year 2028:
#
# ANDHRA PRADESH:
#   Rape: 2099
#   Kidnapping and Abduction: 3355
#   Dowry Deaths: 923
#   Assault on women with intent to outrage her modesty: 7637
#   Insult to modesty of Women: 8376
#   Cruelty by Husband or his Relatives: 23755
#
#
# ARUNACHAL PRADESH:
#   Rape: 89
#   Kidnapping and Abduction: 24
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 88
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 20
#
#
# ASSAM:
#   Rape: 3360
#   Kidnapping and Abduction: 13474
#   Dowry Deaths: 380
#   Assault on women with intent to outrage her modesty: 2359
#   Insult to modesty of Women: 28
#   Cruelty by Husband or his Relatives: 23407
#
#
# BIHAR:
#   Rape: 1201
#   Kidnapping and Abduction: 6686
#   Dowry Deaths: 2213
#   Assault on women with intent to outrage her modesty: 1016
#   Insult to modesty of Women: 29
#   Cruelty by Husband or his Relatives: 3390
#
#
# CHHATTISGARH:
#   Rape: 1085
#   Kidnapping and Abduction: 443
#   Dowry Deaths: 223
#   Assault on women with intent to outrage her modesty: 1699
#   Insult to modesty of Women: 176
#   Cruelty by Husband or his Relatives: 1264
#
#
# GOA:
#   Rape: 82
#   Kidnapping and Abduction: 53
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 72
#   Insult to modesty of Women: 24
#   Cruelty by Husband or his Relatives: 26
#
#
# GUJARAT:
#   Rape: 731
#   Kidnapping and Abduction: 2122
#   Dowry Deaths: -75
#   Assault on women with intent to outrage her modesty: 717
#   Insult to modesty of Women: 133
#   Cruelty by Husband or his Relatives: 11631
#
#
# HARYANA:
#   Rape: 1378
#   Kidnapping and Abduction: 1546
#   Dowry Deaths: 352
#   Assault on women with intent to outrage her modesty: 509
#   Insult to modesty of Women: -506
#   Cruelty by Husband or his Relatives: 5348
#
#
# HIMACHAL PRADESH:
#   Rape: 253
#   Kidnapping and Abduction: 245
#   Dowry Deaths: -12
#   Assault on women with intent to outrage her modesty: 388
#   Insult to modesty of Women: 156
#   Cruelty by Husband or his Relatives: 396
#
#
# JAMMU & KASHMIR:
#   Rape: 400
#   Kidnapping and Abduction: 1374
#   Dowry Deaths: 9
#   Assault on women with intent to outrage her modesty: 1645
#   Insult to modesty of Women: 279
#   Cruelty by Husband or his Relatives: 563
#
#
# JHARKHAND:
#   Rape: 1019
#   Kidnapping and Abduction: 1544
#   Dowry Deaths: 380
#   Assault on women with intent to outrage her modesty: 30
#   Insult to modesty of Women: 133
#   Cruelty by Husband or his Relatives: 1266
#
#
# KARNATAKA:
#   Rape: 1111
#   Kidnapping and Abduction: 997
#   Dowry Deaths: 346
#   Assault on women with intent to outrage her modesty: 4414
#   Insult to modesty of Women: 87
#   Cruelty by Husband or his Relatives: 7369
#
#
# KERALA:
#   Rape: 832
#   Kidnapping and Abduction: 399
#   Dowry Deaths: 20
#   Assault on women with intent to outrage her modesty: 4739
#   Insult to modesty of Women: 1251
#   Cruelty by Husband or his Relatives: 8610
#
#
# MADHYA PRADESH:
#   Rape: 3564
#   Kidnapping and Abduction: 1754
#   Dowry Deaths: 1378
#   Assault on women with intent to outrage her modesty: 5104
#   Insult to modesty of Women: 953
#   Cruelty by Husband or his Relatives: 5627
#
#
# MAHARASHTRA:
#   Rape: 2152
#   Kidnapping and Abduction: 2076
#   Dowry Deaths: 570
#   Assault on women with intent to outrage her modesty: 5546
#   Insult to modesty of Women: 1723
#   Cruelty by Husband or his Relatives: 12841
#
#
# MANIPUR:
#   Rape: 72
#   Kidnapping and Abduction: 168
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 63
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 64
#
#
# MEGHALAYA:
#   Rape: 815
#   Kidnapping and Abduction: 80
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 151
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 86
#
#
# MIZORAM:
#   Rape: 167
#   Kidnapping and Abduction: -3
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 76
#   Insult to modesty of Women: 1
#   Cruelty by Husband or his Relatives: -9
#
#
# NAGALAND:
#   Rape: 23
#   Kidnapping and Abduction: 14
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 34
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 5
#
#
# ODISHA:
#   Rape: 1850
#   Kidnapping and Abduction: 1895
#   Dowry Deaths: 760
#   Assault on women with intent to outrage her modesty: 6009
#   Insult to modesty of Women: 85
#   Cruelty by Husband or his Relatives: 3112
#
#
# PUNJAB:
#   Rape: 1089
#   Kidnapping and Abduction: 1136
#   Dowry Deaths: 68
#   Assault on women with intent to outrage her modesty: 391
#   Insult to modesty of Women: -144
#   Cruelty by Husband or his Relatives: 1269
#
#
# RAJASTHAN:
#   Rape: 2590
#   Kidnapping and Abduction: 3761
#   Dowry Deaths: 611
#   Assault on women with intent to outrage her modesty: 1445
#   Insult to modesty of Women: -41
#   Cruelty by Husband or his Relatives: 21146
#
#
# SIKKIM:
#   Rape: 54
#   Kidnapping and Abduction: 18
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: -16
#   Cruelty by Husband or his Relatives: 16
#
#
# TAMIL NADU:
#   Rape: 892
#   Kidnapping and Abduction: 2869
#   Dowry Deaths: 107
#   Assault on women with intent to outrage her modesty: 152
#   Insult to modesty of Women: -696
#   Cruelty by Husband or his Relatives: 2986
#
#
# TRIPURA:
#   Rape: 471
#   Kidnapping and Abduction: 244
#   Dowry Deaths: 52
#   Assault on women with intent to outrage her modesty: 1052
#   Insult to modesty of Women: 22
#   Cruelty by Husband or his Relatives: 2356
#
#
# UTTAR PRADESH:
#   Rape: 2119
#   Kidnapping and Abduction: 11516
#   Dowry Deaths: 3063
#   Assault on women with intent to outrage her modesty: 4366
#   Insult to modesty of Women: -918
#   Cruelty by Husband or his Relatives: 14868
#
#
# UTTARAKHAND:
#   Rape: 178
#   Kidnapping and Abduction: 527
#   Dowry Deaths: 109
#   Assault on women with intent to outrage her modesty: 129
#   Insult to modesty of Women: 508
#   Cruelty by Husband or his Relatives: 481
#
#
# WEST BENGAL:
#   Rape: 6233
#   Kidnapping and Abduction: 10986
#   Dowry Deaths: 991
#   Assault on women with intent to outrage her modesty: 5658
#   Insult to modesty of Women: 323
#   Cruelty by Husband or his Relatives: 48215
#
#
# A & N ISLANDS:
#   Rape: 54
#   Kidnapping and Abduction: 36
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 55
#   Insult to modesty of Women: 19
#   Cruelty by Husband or his Relatives: 46
#
#
# CHANDIGARH:
#   Rape: 50
#   Kidnapping and Abduction: 17
#   Dowry Deaths: 7
#   Assault on women with intent to outrage her modesty: 30
#   Insult to modesty of Women: -31
#   Cruelty by Husband or his Relatives: 60
#
#
# D & N HAVELI:
#   Rape: 5
#   Kidnapping and Abduction: 26
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 4
#
#
# DAMAN & DIU:
#   Rape: 0
#   Kidnapping and Abduction: -2
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 5
#
#
# LAKSHADWEEP:
#   Rape: 1
#   Kidnapping and Abduction: 1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 0
#   Insult to modesty of Women: 0
#   Cruelty by Husband or his Relatives: 1
#
#
# PUDUCHERRY:
#   Rape: 0
#   Kidnapping and Abduction: 31
#   Dowry Deaths: -3
#   Assault on women with intent to outrage her modesty: 86
#   Insult to modesty of Women: 9
#   Cruelty by Husband or his Relatives: 28
#
#
# TELANGANA:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available
#
#
# DELHI:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available

# %%
forecast_crimes_for_all_states()
# Out:
# Enter the year you want to forecast (e.g., 2025): 2029
#
# Forecasted crime rates for all states for the year 2029:
#
# ANDHRA PRADESH:
#   Rape: 2145
#   Kidnapping and Abduction: 3451
#   Dowry Deaths: 941
#   Assault on women with intent to outrage her modesty: 7789
#   Insult to modesty of Women: 8621
#   Cruelty by Husband or his Relatives: 24401
#
#
# ARUNACHAL PRADESH:
#   Rape: 91
#   Kidnapping and Abduction: 23
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 89
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 20
#
#
# ASSAM:
#   Rape: 3453
#   Kidnapping and Abduction: 14071
#   Dowry Deaths: 393
#   Assault on women with intent to outrage her modesty: 2417
#   Insult to modesty of Women: 29
#   Cruelty by Husband or his Relatives: 24408
#
#
# BIHAR:
#   Rape: 1205
#   Kidnapping and Abduction: 6918
#   Dowry Deaths: 2263
#   Assault on women with intent to outrage her modesty: 1032
#   Insult to modesty of Women: 30
#   Cruelty by Husband or his Relatives: 3455
#
#
# CHHATTISGARH:
#   Rape: 1090
#   Kidnapping and Abduction: 455
#   Dowry Deaths: 228
#   Assault on women with intent to outrage her modesty: 1704
#   Insult to modesty of Women: 178
#   Cruelty by Husband or his Relatives: 1286
#
#
# GOA:
#   Rape: 84
#   Kidnapping and Abduction: 55
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 75
#   Insult to modesty of Women: 25
#   Cruelty by Husband or his Relatives: 26
#
#
# GUJARAT:
#   Rape: 748
#   Kidnapping and Abduction: 2172
#   Dowry Deaths: -80
#   Assault on women with intent to outrage her modesty: 715
#   Insult to modesty of Women: 134
#   Cruelty by Husband or his Relatives: 11940
#
#
# HARYANA:
#   Rape: 1417
#   Kidnapping and Abduction: 1592
#   Dowry Deaths: 356
#   Assault on women with intent to outrage her modesty: 513
#   Insult to modesty of Women: -561
#   Cruelty by Husband or his Relatives: 5492
#
#
# HIMACHAL PRADESH:
#   Rape: 258
#   Kidnapping and Abduction: 251
#   Dowry Deaths: -12
#   Assault on women with intent to outrage her modesty: 392
#   Insult to modesty of Women: 162
#   Cruelty by Husband or his Relatives: 401
#
#
# JAMMU & KASHMIR:
#   Rape: 408
#   Kidnapping and Abduction: 1405
#   Dowry Deaths: 9
#   Assault on women with intent to outrage her modesty: 1679
#   Insult to modesty of Women: 277
#   Cruelty by Husband or his Relatives: 583
#
#
# JHARKHAND:
#   Rape: 1030
#   Kidnapping and Abduction: 1595
#   Dowry Deaths: 385
#   Assault on women with intent to outrage her modesty: 16
#   Insult to modesty of Women: 138
#   Cruelty by Husband or his Relatives: 1293
#
#
# KARNATAKA:
#   Rape: 1143
#   Kidnapping and Abduction: 1026
#   Dowry Deaths: 351
#   Assault on women with intent to outrage her modesty: 4518
#   Insult to modesty of Women: 87
#   Cruelty by Husband or his Relatives: 7587
#
#
# KERALA:
#   Rape: 846
#   Kidnapping and Abduction: 410
#   Dowry Deaths: 19
#   Assault on women with intent to outrage her modesty: 4843
#   Insult to modesty of Women: 1297
#   Cruelty by Husband or his Relatives: 8834
#
#
# MADHYA PRADESH:
#   Rape: 3593
#   Kidnapping and Abduction: 1794
#   Dowry Deaths: 1406
#   Assault on women with intent to outrage her modesty: 5035
#   Insult to modesty of Women: 961
#   Cruelty by Husband or his Relatives: 5734
#
#
# MAHARASHTRA:
#   Rape: 2183
#   Kidnapping and Abduction: 2131
#   Dowry Deaths: 579
#   Assault on women with intent to outrage her modesty: 5653
#   Insult to modesty of Women: 1757
#   Cruelty by Husband or his Relatives: 13120
#
#
# MANIPUR:
#   Rape: 74
#   Kidnapping and Abduction: 171
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 64
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 67
#
#
# MEGHALAYA:
#   Rape: 852
#   Kidnapping and Abduction: 83
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 156
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 90
#
#
# MIZORAM:
#   Rape: 171
#   Kidnapping and Abduction: -3
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 77
#   Insult to modesty of Women: 1
#   Cruelty by Husband or his Relatives: -10
#
#
# NAGALAND:
#   Rape: 24
#   Kidnapping and Abduction: 15
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 35
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 5
#
#
# ODISHA:
#   Rape: 1893
#   Kidnapping and Abduction: 1953
#   Dowry Deaths: 778
#   Assault on women with intent to outrage her modesty: 6176
#   Insult to modesty of Women: 78
#   Cruelty by Husband or his Relatives: 3189
#
#
# PUNJAB:
#   Rape: 1118
#   Kidnapping and Abduction: 1168
#   Dowry Deaths: 66
#   Assault on women with intent to outrage her modesty: 393
#   Insult to modesty of Women: -153
#   Cruelty by Husband or his Relatives: 1275
#
#
# RAJASTHAN:
#   Rape: 2646
#   Kidnapping and Abduction: 3832
#   Dowry Deaths: 620
#   Assault on women with intent to outrage her modesty: 1394
#   Insult to modesty of Women: -45
#   Cruelty by Husband or his Relatives: 21754
#
#
# SIKKIM:
#   Rape: 56
#   Kidnapping and Abduction: 19
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: -17
#   Cruelty by Husband or his Relatives: 16
#
#
# TAMIL NADU:
#   Rape: 907
#   Kidnapping and Abduction: 2956
#   Dowry Deaths: 103
#   Assault on women with intent to outrage her modesty: 86
#   Insult to modesty of Women: -768
#   Cruelty by Husband or his Relatives: 3055
#
#
# TRIPURA:
#   Rape: 485
#   Kidnapping and Abduction: 252
#   Dowry Deaths: 53
#   Assault on women with intent to outrage her modesty: 1089
#   Insult to modesty of Women: 23
#   Cruelty by Husband or his Relatives: 2438
#
#
# UTTAR PRADESH:
#   Rape: 2147
#   Kidnapping and Abduction: 11885
#   Dowry Deaths: 3114
#   Assault on women with intent to outrage her modesty: 4458
#   Insult to modesty of Women: -1076
#   Cruelty by Husband or his Relatives: 15250
#
#
# UTTARAKHAND:
#   Rape: 181
#   Kidnapping and Abduction: 543
#   Dowry Deaths: 111
#   Assault on women with intent to outrage her modesty: 129
#   Insult to modesty of Women: 524
#   Cruelty by Husband or his Relatives: 487
#
#
# WEST BENGAL:
#   Rape: 6437
#   Kidnapping and Abduction: 11446
#   Dowry Deaths: 1018
#   Assault on women with intent to outrage her modesty: 5833
#   Insult to modesty of Women: 334
#   Cruelty by Husband or his Relatives: 49905
#
#
# A & N ISLANDS:
#   Rape: 56
#   Kidnapping and Abduction: 37
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 56
#   Insult to modesty of Women: 20
#   Cruelty by Husband or his Relatives: 47
#
#
# CHANDIGARH:
#   Rape: 51
#   Kidnapping and Abduction: 16
#   Dowry Deaths: 7
#   Assault on women with intent to outrage her modesty: 30
#   Insult to modesty of Women: -33
#   Cruelty by Husband or his Relatives: 59
#
#
# D & N HAVELI:
#   Rape: 5
#   Kidnapping and Abduction: 27
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 4
#
#
# DAMAN & DIU:
#   Rape: 0
#   Kidnapping and Abduction: -2
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 5
#
#
# LAKSHADWEEP:
#   Rape: 1
#   Kidnapping and Abduction: 1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 0
#   Insult to modesty of Women: 0
#   Cruelty by Husband or his Relatives: 1
#
#
# PUDUCHERRY:
#   Rape: 0
#   Kidnapping and Abduction: 32
#   Dowry Deaths: -4
#   Assault on women with intent to outrage her modesty: 88
#   Insult to modesty of Women: 9
#   Cruelty by Husband or his Relatives: 29
#
#
# TELANGANA:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available
#
#
# DELHI:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available

# %%
forecast_crimes_for_all_states()
# Out:
# Enter the year you want to forecast (e.g., 2025): 2030
#
# Forecasted crime rates for all states for the year 2030:
#
# ANDHRA PRADESH:
#   Rape: 2191
#   Kidnapping and Abduction: 3547
#   Dowry Deaths: 960
#   Assault on women with intent to outrage her modesty: 7940
#   Insult to modesty of Women: 8865
#   Cruelty by Husband or his Relatives: 25046
#
#
# ARUNACHAL PRADESH:
#   Rape: 93
#   Kidnapping and Abduction: 22
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 90
#   Insult to modesty of Women: 5
#   Cruelty by Husband or his Relatives: 21
#
#
# ASSAM:
#   Rape: 3545
#   Kidnapping and Abduction: 14669
#   Dowry Deaths: 405
#   Assault on women with intent to outrage her modesty: 2475
#   Insult to modesty of Women: 30
#   Cruelty by Husband or his Relatives: 25409
#
#
# BIHAR:
#   Rape: 1208
#   Kidnapping and Abduction: 7149
#   Dowry Deaths: 2313
#   Assault on women with intent to outrage her modesty: 1048
#   Insult to modesty of Women: 30
#   Cruelty by Husband or his Relatives: 3519
#
#
# CHHATTISGARH:
#   Rape: 1095
#   Kidnapping and Abduction: 466
#   Dowry Deaths: 234
#   Assault on women with intent to outrage her modesty: 1708
#   Insult to modesty of Women: 180
#   Cruelty by Husband or his Relatives: 1308
#
#
# GOA:
#   Rape: 87
#   Kidnapping and Abduction: 56
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 77
#   Insult to modesty of Women: 26
#   Cruelty by Husband or his Relatives: 27
#
#
# GUJARAT:
#   Rape: 766
#   Kidnapping and Abduction: 2222
#   Dowry Deaths: -85
#   Assault on women with intent to outrage her modesty: 713
#   Insult to modesty of Women: 135
#   Cruelty by Husband or his Relatives: 12250
#
#
# HARYANA:
#   Rape: 1456
#   Kidnapping and Abduction: 1638
#   Dowry Deaths: 360
#   Assault on women with intent to outrage her modesty: 516
#   Insult to modesty of Women: -615
#   Cruelty by Husband or his Relatives: 5635
#
#
# HIMACHAL PRADESH:
#   Rape: 263
#   Kidnapping and Abduction: 256
#   Dowry Deaths: -13
#   Assault on women with intent to outrage her modesty: 396
#   Insult to modesty of Women: 167
#   Cruelty by Husband or his Relatives: 407
#
#
# JAMMU & KASHMIR:
#   Rape: 416
#   Kidnapping and Abduction: 1436
#   Dowry Deaths: 9
#   Assault on women with intent to outrage her modesty: 1712
#   Insult to modesty of Women: 275
#   Cruelty by Husband or his Relatives: 602
#
#
# JHARKHAND:
#   Rape: 1042
#   Kidnapping and Abduction: 1647
#   Dowry Deaths: 389
#   Assault on women with intent to outrage her modesty: 2
#   Insult to modesty of Women: 143
#   Cruelty by Husband or his Relatives: 1321
#
#
# KARNATAKA:
#   Rape: 1175
#   Kidnapping and Abduction: 1054
#   Dowry Deaths: 355
#   Assault on women with intent to outrage her modesty: 4622
#   Insult to modesty of Women: 88
#   Cruelty by Husband or his Relatives: 7806
#
#
# KERALA:
#   Rape: 859
#   Kidnapping and Abduction: 422
#   Dowry Deaths: 19
#   Assault on women with intent to outrage her modesty: 4947
#   Insult to modesty of Women: 1343
#   Cruelty by Husband or his Relatives: 9059
#
#
# MADHYA PRADESH:
#   Rape: 3621
#   Kidnapping and Abduction: 1834
#   Dowry Deaths: 1434
#   Assault on women with intent to outrage her modesty: 4966
#   Insult to modesty of Women: 968
#   Cruelty by Husband or his Relatives: 5841
#
#
# MAHARASHTRA:
#   Rape: 2214
#   Kidnapping and Abduction: 2185
#   Dowry Deaths: 589
#   Assault on women with intent to outrage her modesty: 5759
#   Insult to modesty of Women: 1790
#   Cruelty by Husband or his Relatives: 13398
#
#
# MANIPUR:
#   Rape: 76
#   Kidnapping and Abduction: 175
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 65
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 69
#
#
# MEGHALAYA:
#   Rape: 889
#   Kidnapping and Abduction: 85
#   Dowry Deaths: 4
#   Assault on women with intent to outrage her modesty: 160
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 93
#
#
# MIZORAM:
#   Rape: 176
#   Kidnapping and Abduction: -3
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 77
#   Insult to modesty of Women: 1
#   Cruelty by Husband or his Relatives: -10
#
#
# NAGALAND:
#   Rape: 24
#   Kidnapping and Abduction: 15
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 37
#   Insult to modesty of Women: 5
#   Cruelty by Husband or his Relatives: 6
#
#
# ODISHA:
#   Rape: 1936
#   Kidnapping and Abduction: 2011
#   Dowry Deaths: 796
#   Assault on women with intent to outrage her modesty: 6343
#   Insult to modesty of Women: 72
#   Cruelty by Husband or his Relatives: 3266
#
#
# PUNJAB:
#   Rape: 1147
#   Kidnapping and Abduction: 1200
#   Dowry Deaths: 63
#   Assault on women with intent to outrage her modesty: 395
#   Insult to modesty of Women: -163
#   Cruelty by Husband or his Relatives: 1281
#
#
# RAJASTHAN:
#   Rape: 2703
#   Kidnapping and Abduction: 3904
#   Dowry Deaths: 630
#   Assault on women with intent to outrage her modesty: 1342
#   Insult to modesty of Women: -48
#   Cruelty by Husband or his Relatives: 22363
#
#
# SIKKIM:
#   Rape: 57
#   Kidnapping and Abduction: 20
#   Dowry Deaths: 1
#   Assault on women with intent to outrage her modesty: 6
#   Insult to modesty of Women: -17
#   Cruelty by Husband or his Relatives: 17
#
#
# TAMIL NADU:
#   Rape: 922
#   Kidnapping and Abduction: 3044
#   Dowry Deaths: 98
#   Assault on women with intent to outrage her modesty: 20
#   Insult to modesty of Women: -840
#   Cruelty by Husband or his Relatives: 3124
#
#
# TRIPURA:
#   Rape: 499
#   Kidnapping and Abduction: 260
#   Dowry Deaths: 55
#   Assault on women with intent to outrage her modesty: 1126
#   Insult to modesty of Women: 24
#   Cruelty by Husband or his Relatives: 2521
#
#
# UTTAR PRADESH:
#   Rape: 2174
#   Kidnapping and Abduction: 12254
#   Dowry Deaths: 3164
#   Assault on women with intent to outrage her modesty: 4550
#   Insult to modesty of Women: -1235
#   Cruelty by Husband or his Relatives: 15631
#
#
# UTTARAKHAND:
#   Rape: 184
#   Kidnapping and Abduction: 558
#   Dowry Deaths: 112
#   Assault on women with intent to outrage her modesty: 129
#   Insult to modesty of Women: 541
#   Cruelty by Husband or his Relatives: 493
#
#
# WEST BENGAL:
#   Rape: 6642
#   Kidnapping and Abduction: 11906
#   Dowry Deaths: 1045
#   Assault on women with intent to outrage her modesty: 6008
#   Insult to modesty of Women: 344
#   Cruelty by Husband or his Relatives: 51594
#
#
# A & N ISLANDS:
#   Rape: 58
#   Kidnapping and Abduction: 39
#   Dowry Deaths: 3
#   Assault on women with intent to outrage her modesty: 58
#   Insult to modesty of Women: 21
#   Cruelty by Husband or his Relatives: 49
#
#
# CHANDIGARH:
#   Rape: 52
#   Kidnapping and Abduction: 15
#   Dowry Deaths: 8
#   Assault on women with intent to outrage her modesty: 31
#   Insult to modesty of Women: -35
#   Cruelty by Husband or his Relatives: 59
#
#
# D & N HAVELI:
#   Rape: 5
#   Kidnapping and Abduction: 28
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 4
#   Cruelty by Husband or his Relatives: 4
#
#
# DAMAN & DIU:
#   Rape: 0
#   Kidnapping and Abduction: -2
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 7
#   Insult to modesty of Women: 2
#   Cruelty by Husband or his Relatives: 5
#
#
# LAKSHADWEEP:
#   Rape: 1
#   Kidnapping and Abduction: 1
#   Dowry Deaths: 0
#   Assault on women with intent to outrage her modesty: 0
#   Insult to modesty of Women: 0
#   Cruelty by Husband or his Relatives: 1
#
#
# PUDUCHERRY:
#   Rape: 0
#   Kidnapping and Abduction: 33
#   Dowry Deaths: -4
#   Assault on women with intent to outrage her modesty: 89
#   Insult to modesty of Women: 8
#   Cruelty by Husband or his Relatives: 30
#
#
# TELANGANA:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available
#
#
# DELHI:
#   Rape: No data available
#   Kidnapping and Abduction: No data available
#   Dowry Deaths: No data available
#   Assault on women with intent to outrage her modesty: No data available
#   Insult to modesty of Women: No data available
#   Cruelty by Husband or his Relatives: No data available

# %% [markdown]
# **Time-Series Analysis and Forecasting (Holt-Winters)**

# %%
# Step 1: Aggregate Data at National Level by Year
crime_types = ['Rape', 'Kidnapping and Abduction', 'Dowry Deaths',
               'Assault on women with intent to outrage her modesty',
               'Insult to modesty of Women', 'Cruelty by Husband or his Relatives']
annual_data = df.groupby('Year')[crime_types].sum()

# Step 2: Scale data for forecasting
scaler = MinMaxScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(annual_data), columns=annual_data.columns, index=annual_data.index)

# %%
# Step 3: Train/Test Split
train_data = scaled_data.iloc[:int(len(scaled_data) * 0.8)]
test_data = scaled_data.iloc[int(len(scaled_data) * 0.8):]

# Forecasting and Model Evaluation
results = {}
for crime_type in crime_types:
    model = ExponentialSmoothing(train_data[crime_type], trend='add', seasonal=None).fit()
    test_predictions = model.forecast(len(test_data))
    mae = mean_absolute_error(test_data[crime_type], test_predictions)
    rmse = mean_squared_error(test_data[crime_type], test_predictions, squared=False)
    results[crime_type] = {'MAE': mae, 'RMSE': rmse}

    plt.figure(figsize=(10, 6))
    plt.plot(train_data[crime_type], label='Train', color='black')
    plt.plot(test_data[crime_type], label='Test', color='green')
    plt.plot(test_predictions, label='Prediction', color='red')
    plt.title(f'Holt-Winters Forecast for {crime_type}')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

print("Model Evaluation (MAE and RMSE) for each crime type:")
for crime_type, metrics in results.items():
    print(f"{crime_type}: MAE = {metrics['MAE']:.2f}, RMSE = {metrics['RMSE']:.2f}")
# Out:
# Model Evaluation (MAE and RMSE) for each crime type:
# Rape: MAE = 0.50, RMSE = 0.52
# Kidnapping and Abduction: MAE = 0.14, RMSE = 0.18
# Dowry Deaths: MAE = 0.53, RMSE = 0.54
# Assault on women with intent to outrage her modesty: MAE = 0.09, RMSE = 0.10
# Insult to modesty of Women: MAE = 1.48, RMSE = 1.49
# Cruelty by Husband or his Relatives: MAE = 0.11, RMSE = 0.13

# %%
# Step 4: Final Model for 10-Year Forecast
forecasts = {}
for crime_type in crime_types:
    final_model = ExponentialSmoothing(scaled_data[crime_type], trend='add', seasonal=None).fit()
    future_forecast = final_model.forecast(10)  # Forecast for the next 10 years

    # Inverse transform forecast to original scale
    scaler.fit(annual_data[crime_type].values.reshape(-1, 1))
    forecast_rescaled = scaler.inverse_transform(future_forecast.values.reshape(-1, 1))
    forecasts[crime_type] = forecast_rescaled.flatten()

    plt.figure(figsize=(10, 6))
    plt.plot(annual_data[crime_type], label='Observed', color='black')
    future_years = range(annual_data.index.max() + 1, annual_data.index.max() + 11)
    plt.plot(pd.Series(forecast_rescaled.flatten(), index=future_years), label='Forecast', color='red')
    plt.title(f'{crime_type} - Historical Data with 10-Year Forecast')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

print("10-Year Forecasts for each crime type:")
for crime_type, forecast in forecasts.items():
    print(f"{crime_type} Forecast for next 10 years: {forecast}")
# Out:
# 10-Year Forecasts for each crime type:
# Rape Forecast for next 10 years: [32186.90550882 32976.39120768 33765.87690654 34555.3626054
#  35344.84830426 36134.33400312 36923.81970198 37713.30540084
#  38502.7910997  39292.27679856]
# Kidnapping and Abduction Forecast for next 10 years: [ 77209.39580973  80263.52852141  83317.66123309  86371.79394476
#   89425.92665644  92480.05936811  95534.19207979  98588.32479147
#  101642.45750314 104696.59021482]
# Dowry Deaths Forecast for next 10 years: [6363.44131563 6106.65672759 5849.87213956 5593.08755153 5336.30296349
#  5079.51837546 4822.73378743 4565.94919939 4309.16461136 4052.38002333]
# Assault on women with intent to outrage her modesty Forecast for next 10 years: [ 92105.05145782  94922.76095749  97740.47045715 100558.17995682
#  103375.88945649 106193.59895616 109011.30845583 111829.0179555
#  114646.72745516 117464.43695483]
# Insult to modesty of Women Forecast for next 10 years: [7694.67154971 7601.34311158 7508.01467346 7414.68623533 7321.3577972
#  7228.02935908 7134.70092095 7041.37248283 6948.0440447  6854.71560657]
# Cruelty by Husband or his Relatives Forecast for next 10 years: [135851.72171044 140051.65254295 144251.58337547 148451.51420799
#  152651.44504051 156851.37587303 161051.30670554 165251.23753806
#  169451.16837058 173651.0992031 ]

# %%
import matplotlib.pyplot as plt

# Define crime types
crime_types = [
    'Rape',
    'Kidnapping and Abduction',
    'Dowry Deaths',
    'Assault on women with intent to outrage her modesty',
    'Insult to modesty of Women',
    'Cruelty by Husband or his Relatives'
]

# Prepare a figure with subplots arranged in a 2x3 grid
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

# Plot trends for each crime type from 2001 to 2021
for i, crime in enumerate(crime_types):
    # Aggregate data for each crime type over the years
    crime_data = df.groupby('Year')[crime].sum()

    # Plot historical data
    axes[i].plot(crime_data.index, crime_data.values, marker='o', color='blue')

    # Set titles, labels, and styling to match the example format
    axes[i].set_title(f'{crime}', fontsize=14)
    axes[i].set_xlabel('Year', fontsize=12)
    axes[i].set_ylabel('Number of Cases', fontsize=12)
    axes[i].grid(True)

# Adjust layout to ensure no overlap and improve spacing
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Define crime types
crime_types = ['Rape', 'Kidnapping and Abduction', 'Dowry Deaths',
               'Assault on women with intent to outrage her modesty',
               'Insult to modesty of Women', 'Cruelty by Husband or his Relatives']

# Prepare a figure with subplots for each crime type
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

# Forecasting and plotting for each crime type
for i, crime in enumerate(crime_types):
    # Aggregate data for each crime type over the years
    crime_data = df.groupby('Year')[crime].sum()

    # Fit the Holt-Winters model to historical data
    model = ExponentialSmoothing(crime_data, trend='add', seasonal=None).fit()

    # Forecast for 10 years into the future (2021-2030)
    future_forecast = model.forecast(10)

    # Plot historical data
    axes[i].plot(crime_data.index, crime_data.values, marker='o', color='blue', label='Historical')

    # Plot forecasted data
    forecast_years = range(2021, 2031)
    axes[i].plot(forecast_years, future_forecast.values, marker='o', color='red', linestyle='--', label='Forecast')

    # Set titles and labels
    axes[i].set_title(crime)
    axes[i].set_xlabel('Year')
    axes[i].set_ylabel('Number of Cases')
    axes[i].grid(True)
    axes[i].legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/content/CrimesOnWomenData-dataset.csv')

# Aggregate data by year
df_yearly = df.groupby('Year').sum().reset_index()

# Define a function to forecast and plot
def forecast_and_plot(actual_values, title, ylabel):
    # Train the Exponential Smoothing model on the actual values
    model = ExponentialSmoothing(actual_values, trend="add", seasonal="add", seasonal_periods=5).fit()
    predictions = model.fittedvalues

    # Plot predicted vs actual values
    plt.scatter(actual_values, predictions, color='red')
    plt.plot([min(actual_values), max(actual_values)], [min(actual_values), max(actual_values)], color='blue')
    plt.xlabel(f"Actual - {ylabel}")
    plt.ylabel(f"Predicted - {ylabel}")
    plt.title(title)
    plt.show()

# Apply the function for each crime category
forecast_and_plot(df_yearly['Rape'], "Predicted vs Actual for Rape", "Rape")
forecast_and_plot(df_yearly['Kidnapping and Abduction'], "Predicted vs Actual for Kidnapping and Abduction", "Kidnapping and Abduction")
forecast_and_plot(df_yearly['Assault on women with intent to outrage her modesty'], "Predicted vs Actual for Assault on Women with Intent to Outrage Her Modesty", "Assault on Women with Intent to Outrage Her Modesty")
forecast_and_plot(df_yearly['Insult to modesty of Women'], "Predicted vs Actual for Insult to Modesty of Women", "Insult to Modesty of Women")
forecast_and_plot(df_yearly['Cruelty by Husband or his Relatives'], "Predicted vs Actual for Cruelty by Husband or His Relatives", "Cruelty by Husband or His Relatives")

# %%
# Predictive Modeling (Random Forest)
# Prepare dataset for Random Forest
statewise_data = df.groupby(['State', 'Year']).sum().reset_index()
X = statewise_data[['Year', 'Kidnapping and Abduction', 'Dowry Deaths',
                    'Assault on women with intent to outrage her modesty',
                    'Insult to modesty of Women', 'Cruelty by Husband or his Relatives']]
y = statewise_data['Rape']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict and evaluate
y_pred = rf_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nRandom Forest - Mean Absolute Error: {mae:.2f}")
print(f"Random Forest - R² Score: {r2:.2f}")
# Out:
# Random Forest - Mean Absolute Error: 171.06
# Random Forest - R² Score: 0.90
